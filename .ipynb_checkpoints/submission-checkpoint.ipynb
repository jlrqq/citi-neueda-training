# %% [markdown]
# # Loan Defaulter Detection

# %% [markdown]
# ### A. Import dependencies

# %%
import pandas as pd
from matplotlib import pyplot
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### B. Import / Explore the Dataset
# Ensure that you have the Loan_Default.csv in the root directory for this, the link to the Kaggle site can be found in the README file.

# %%
df = pd.read_csv("Loan_Default.csv")

# Let's take a look at the first 5 rows
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# 0          EXP           758                       CIB  25-34
# 1         EQUI           552                       EXP  55-64
# 2          EXP           834                       CIB  35-44
# 3          EXP           587                       CIB  45-54
# 4         CRIF           602                       EXP  25-34
#
#    submission_of_application        LTV Region Security_Type  Status dtir1
# 0                    to_inst  98.728814  south        direct       1  45.0
# 1                    to_inst        NaN  North        direct       1   NaN
# 2                    to_inst  80.019685  south        direct       0  46.0
# 3                   not_inst  69.376900  North        direct       0  42.0
# 4                   not_inst  91.886544  North        direct       0  39.0
#
# [5 rows x 34 columns]

# %% [markdown]
# ### C. Data Cleaning / Preparation

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# Look at the column breakdown for the dataset first, to see what we may be dealing with

# %%
# Reveals column information, such as number of rows that are not null, and the data type held
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   credit_worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  interest_rate_spread       112031 non-null  float64
#  13  upfront_charges            109028 non-null  float64
#  14  term                       148629 non-null  float64
#  15  neg_ammortization          148549 non-null  object
#  16  interest_only              148670 non-null  object
#  17  lump_sum_payment           148670 non-null  object
#  18  property_value             133572 non-null  float64
#  19  construction_type          148670 non-null  object
#  20  occupancy_type             148670 non-null  object
#  21  secured_by                 148670 non-null  object
#  22  total_units                148670 non-null  object
#  23  income                     139520 non-null  float64
#  24  credit_type                148670 non-null  object
#  25  credit_score               148670 non-null  int64
#  26  co-applicant_credit_type   148670 non-null  object
#  27  age                        148470 non-null  object
#  28  submission_of_application  148470 non-null  object
#  29  ltv                        133572 non-null  float64
#  30  region                     148670 non-null  object
#  31  security_type              148670 non-null  object
#  32  status                     148670 non-null  int64
#  33  dtir1                      124549 non-null  float64
# dtypes: float64(8), int64(5), object(21)
# memory usage: 38.6+ MB

# %% [markdown]
# from here, we can see that many of the columns are not completely filled with non-null values. We can drop those rows since training any model using them will cause incomplete data to be used, which can negatively affect results.
#
# *We cannot remove the rate of interest, interest_rate_spread, upfront_charges row in the end as it removes majority of status = 1*

# %%
no_na_df = df.dropna(subset=df.columns.difference(['rate_of_interest','interest_rate_spread','upfront_charges']))

# All columns in this new dataframe should have the same number of non-null rows
no_na_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120526 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         120526 non-null  int64
#  1   year                       120526 non-null  int64
#  2   loan_limit                 120526 non-null  object
#  3   gender                     120526 non-null  object
#  4   approv_in_adv              120526 non-null  object
#  5   loan_type                  120526 non-null  object
#  6   loan_purpose               120526 non-null  object
#  7   credit_worthiness          120526 non-null  object
#  8   open_credit                120526 non-null  object
#  9   business_or_commercial     120526 non-null  object
#  10  loan_amount                120526 non-null  int64
#  11  rate_of_interest           100879 non-null  float64
#  12  interest_rate_spread       100879 non-null  float64
#  13  upfront_charges            98187 non-null   float64
#  14  term                       120526 non-null  float64
#  15  neg_ammortization          120526 non-null  object
#  16  interest_only              120526 non-null  object
#  17  lump_sum_payment           120526 non-null  object
#  18  property_value             120526 non-null  float64
#  19  construction_type          120526 non-null  object
#  20  occupancy_type             120526 non-null  object
#  21  secured_by                 120526 non-null  object
#  22  total_units                120526 non-null  object
#  23  income                     120526 non-null  float64
#  24  credit_type                120526 non-null  object
#  25  credit_score               120526 non-null  int64
#  26  co-applicant_credit_type   120526 non-null  object
#  27  age                        120526 non-null  object
#  28  submission_of_application  120526 non-null  object
#  29  ltv                        120526 non-null  float64
#  30  region                     120526 non-null  object
#  31  security_type              120526 non-null  object
#  32  status                     120526 non-null  int64
#  33  dtir1                      120526 non-null  float64
# dtypes: float64(8), int64(5), object(21)
# memory usage: 32.2+ MB

# %% [markdown]
# View the 1st 5 rows again (just to revisit the data)

# %%
no_na_df.head()
# Out:
#       id  year loan_limit             gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
# 5  24895  2019         cf              Joint           pre     type1
#
#   loan_purpose credit_worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
# 5           p1                l1        nopc                  nob/c  ...
#
#    credit_type  credit_score  co-applicant_credit_type    age  \
# 0          EXP           758                       CIB  25-34
# 2          EXP           834                       CIB  35-44
# 3          EXP           587                       CIB  45-54
# 4         CRIF           602                       EXP  25-34
# 5          EXP           864                       EXP  35-44
#
#    submission_of_application        ltv region security_type  status dtir1
# 0                    to_inst  98.728814  south        direct       1  45.0
# 2                    to_inst  80.019685  south        direct       0  46.0
# 3                   not_inst  69.376900  North        direct       0  42.0
# 4                   not_inst  91.886544  North        direct       0  39.0
# 5                   not_inst  70.089286  North        direct       0  40.0
#
# [5 rows x 34 columns]

# %%
no_na_df.status.value_counts()
# Out:
# 0    100879
# 1     19647
# Name: status, dtype: int64

# %% [markdown]
# Before visualizing anything, we can first 1-hot encode the data. This converts categorical values into numerical values, to provide standardization such that ML models can work with the data.
#
# The columns that are categorical are:
# 1. loan_limit
# 2. gender
# 3. approv_in_adv
# 4. loan_type
# 5. loan_purpose
# 6. Credit_Worthiness
# 7. open_credit
# 8. business_or_commercial
# 9. neg_ammortization
# 10. Lump_sum_payment
# 11. Construction_type
# 12. Occupancy_type
# 13. Secured_by
# 14. Total_units
# 15. credit_type
# 16. Co-applicant_credit_type
# 17. Age
# 18. Submission_of_application
# 19. Region
# 20. Security_type

# %%
columns_to_encode = [
    'loan_limit',
    'gender',
    'approv_in_adv',
    'loan_type',
    'loan_purpose',
    'credit_worthiness',
    'open_credit',
    'business_or_commercial',
    'neg_ammortization',
    'lump_sum_payment',
    'construction_type',
    'occupancy_type',
    'secured_by',
    'total_units',
    'credit_type',
    'co-applicant_credit_type',
    'age',
    'submission_of_application',
    'region',
    'security_type',
]

# Perform the encoding and view the new df
one_hot_encoded_df = pd.get_dummies(no_na_df, columns=columns_to_encode)
one_hot_encoded_df.head()
# Out:
#       id  year  loan_amount  rate_of_interest  interest_rate_spread  \
# 0  24890  2019       116500               NaN                   NaN
# 2  24892  2019       406500              4.56                0.2000
# 3  24893  2019       456500              4.25                0.6810
# 4  24894  2019       696500              4.00                0.3042
# 5  24895  2019       706500              3.99                0.1523
#
#    upfront_charges   term interest_only  property_value   income  ...  \
# 0              NaN  360.0       not_int        118000.0   1740.0  ...
# 2            595.0  360.0       not_int        508000.0   9480.0  ...
# 3              NaN  360.0       not_int        658000.0  11880.0  ...
# 4              0.0  360.0       not_int        758000.0  10440.0  ...
# 5            370.0  360.0       not_int       1008000.0  10080.0  ...
#
#    age_<25  age_>74  submission_of_application_not_inst  \
# 0        0        0                                   0
# 2        0        0                                   0
# 3        0        0                                   1
# 4        0        0                                   1
# 5        0        0                                   1
#
#    submission_of_application_to_inst  region_North  region_North-East  \
# 0                                  1             0                  0
# 2                                  1             0                  0
# 3                                  0             1                  0
# 4                                  0             1                  0
# 5                                  0             1                  0
#
#    region_central  region_south  security_type_Indriect  security_type_direct
# 0               0             1                       0                     1
# 2               0             1                       0                     1
# 3               0             0                       0                     1
# 4               0             0                       0                     1
# 5               0             0                       0                     1
#
# [5 rows x 71 columns]

# %%
one_hot_encoded_df.columns = one_hot_encoded_df.columns.str.lower()

# %% [markdown]
# Important Columns

# %%
impt_cols = ['dtir1', 'loan_amount', 'loan_type_type1', 'loan_type_type2', 'loan_type_type3', 'credit_worthiness_l1', 'credit_worthiness_l2', 'credit_score', 'income', 'rate_of_interest']

impt_cols_with_no_encoding = ['loan_amount', 'loan_type', 'credit_worthiness', 'rate_of_interest', 'income','credit_score','dtir1', 'status']

# %%
impt_df = one_hot_encoded_df[impt_cols]

# %%
impt_df.head()
# Out:
#    dtir1  loan_amount  loan_type_type1  loan_type_type2  loan_type_type3  \
# 0   45.0       116500                1                0                0
# 2   46.0       406500                1                0                0
# 3   42.0       456500                1                0                0
# 4   39.0       696500                1                0                0
# 5   40.0       706500                1                0                0
#
#    credit_worthiness_l1  credit_worthiness_l2  credit_score   income  \
# 0                     1                     0           758   1740.0
# 2                     1                     0           834   9480.0
# 3                     1                     0           587  11880.0
# 4                     1                     0           602  10440.0
# 5                     1                     0           864  10080.0
#
#    rate_of_interest
# 0               NaN
# 2              4.56
# 3              4.25
# 4              4.00
# 5              3.99

# %% [markdown]
# ## D. EDA

# %% [markdown]
# A statistical summary of the features

# %%
no_na_df.describe()
# Out:
#                   id      year   loan_amount  rate_of_interest  \
# count  120526.000000  120526.0  1.205260e+05     100879.000000
# mean    99133.296492    2019.0  3.293845e+05          4.086293
# std     42915.785917       0.0  1.825916e+05          0.546426
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     61926.250000    2019.0  1.965000e+05          3.750000
# 50%     98978.500000    2019.0  2.965000e+05          3.990000
# 75%    136255.750000    2019.0  4.365000e+05          4.500000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        interest_rate_spread  upfront_charges           term  property_value  \
# count         100879.000000     98187.000000  120526.000000    1.205260e+05
# mean               0.469483      3389.206553     333.673780    5.041113e+05
# std                0.485365      3279.884804      59.963012    3.690127e+05
# min               -3.638000         0.000000      96.000000    1.800000e+04
# 25%                0.105900       822.000000     360.000000    2.780000e+05
# 50%                0.402000      2800.910000     360.000000    4.180000e+05
# 75%                0.780700      4982.500000     360.000000    6.280000e+05
# max                3.357000     60000.000000     360.000000    1.650800e+07
#
#               income   credit_score            ltv         status  \
# count  120526.000000  120526.000000  120526.000000  120526.000000
# mean     7018.242703     699.699932      71.471044       0.163010
# std      6504.565060     115.858601      18.918642       0.369377
# min         0.000000     500.000000       0.967478       0.000000
# 25%      3780.000000     599.000000      59.769539       0.000000
# 50%      5820.000000     699.000000      74.234694       0.000000
# 75%      8580.000000     800.000000      84.763314       0.000000
# max    578580.000000     900.000000     263.541667       1.000000
#
#                dtir1
# count  120526.000000
# mean       37.724922
# std        10.546560
# min         5.000000
# 25%        31.000000
# 50%        39.000000
# 75%        45.000000
# max        61.000000

# %% [markdown]
# Looking at the correlation between features, we can see that these features are highly related.
# - rate_of_interest & interest_rate_spread
# - loan_amount & property_value
# - income & loan_amount

# %%
sns.heatmap(data=no_na_df.corr(), annot=False, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(no_na_df[['loan_amount', 'rate_of_interest','interest_rate_spread','upfront_charges','property_value','income','ltv','dtir1']])

# %% [markdown]
# To look at the distribution of data

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()

no_na_df.loc[:, ~no_na_df.columns.isin(['id','year','term','credit_score'])].hist(ax=ax)
# Out:
# C:\Users\jingy\AppData\Local\Temp\ipykernel_21368\4290396018.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   no_na_df.loc[:, ~no_na_df.columns.isin(['id','year','term','credit_score'])].hist(ax=ax)
# array([[<AxesSubplot: title={'center': 'loan_amount'}>,
#         <AxesSubplot: title={'center': 'rate_of_interest'}>,
#         <AxesSubplot: title={'center': 'interest_rate_spread'}>],
#        [<AxesSubplot: title={'center': 'upfront_charges'}>,
#         <AxesSubplot: title={'center': 'property_value'}>,
#         <AxesSubplot: title={'center': 'income'}>],
#        [<AxesSubplot: title={'center': 'ltv'}>,
#         <AxesSubplot: title={'center': 'status'}>,
#         <AxesSubplot: title={'center': 'dtir1'}>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

sns.countplot(ax=axes[0], data=no_na_df, x='credit_worthiness')
sns.countplot(ax=axes[1],data=no_na_df, x='loan_type')
sns.countplot(ax=axes[2],data=no_na_df, x='credit_type')
# Out:
# <AxesSubplot: xlabel='credit_type', ylabel='count'>

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.boxplot(ax=axes[0,0],data=no_na_df, x='status', y='loan_amount')
sns.boxplot(ax=axes[0,1], data=no_na_df, x='status', y='rate_of_interest')
sns.boxplot(ax=axes[0,2],data=no_na_df, x='status', y='income')
sns.boxplot(ax=axes[1,0],data=no_na_df, x='status', y='dtir1')
sns.boxplot(ax=axes[1,1],data=no_na_df, x='status', y='property_value')
sns.boxplot(ax=axes[1,2],data=no_na_df, x='status', y='ltv')
# Out:
# <AxesSubplot: xlabel='status', ylabel='ltv'>

# %%
# Categorical variables to loan status
fig, axes = plt.subplots(nrows=7, ncols=3, figsize=(15,25))


categorical_variables = ["gender", "approv_in_adv", "loan_type","loan_purpose","credit_worthiness","open_credit","business_or_commercial","loan_type","neg_ammortization","interest_only","lump_sum_payment","construction_type","occupancy_type","secured_by","total_units","credit_type","co-applicant_credit_type","age","submission_of_application","region","security_type"]

i = 0;
while i < 21:
    for row in range(7):
        for col in range(3):
            no_na_df.groupby([categorical_variables[i], "status"]).size().unstack().plot(kind="bar", ax=axes[row,col])
            axes[row, col].tick_params(axis='x', rotation=360)
            i += 1
